# %% [markdown]
# ## Price Check

# %%
"""
Checks price at RedMart, Giant and Coldstorage
Saves as csv file
Displays output using pandas
Show items on promo/ 10 lowest price items
"""

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from datetime import datetime
from bs4 import BeautifulSoup
import csv
import numpy as np
import json
import requests

#------------------------------------------------------------------
#  Lazada
#------------------------------------------------------------------

def get_url(keyword):
    print("RedMart")    
    driver = webdriver.Chrome() 
    driver.get("https://redmart.lazada.sg") 
    elem = driver.find_element_by_name("q") 
    elem.clear() 
    elem.send_keys(keyword) 
    elem.send_keys(Keys.RETURN) 

    keyword_to_url = driver.current_url

    driver.close()
    return keyword_to_url

def collect_data(keyword_to_url):
    resp = requests.get(keyword_to_url)
    soup = BeautifulSoup(resp.text, "html.parser")
    
    data = json.loads(soup.findAll('script', type='application/ld+json')[1].text)    
    data2 = soup.findAll('script')[2].text    
    json_acceptable_string = data2.replace("window.pageData=","")
    data3 = json.loads(json_acceptable_string)
    
    num = int(data3["mainInfo"]["totalResults"])
    last = int(np.ceil(num/40))
    print(f"Downloading {num} items")

    try:
        last_page = np.ceil(num/40) #gives you int of last page
    except:
        last_page = 1

    for pageno in range(1, last+1):

        url = keyword_to_url[:-1] + "&page=" + str(pageno)
        resp = requests.get(url)
        soup = BeautifulSoup(resp.text, "html.parser")
        data = json.loads(soup.findAll('script', type='application/ld+json')[1].text)   
        
        cart = []
        
        len(data['itemListElement'])
        for i in range(len(data['itemListElement'])):
            site = "RedMart"
            name = data['itemListElement'][i]["name"]
            price = data['itemListElement'][i]["offers"]["price"].replace("$","").split("/")[0]
            bundle = None
            size = 1
            image = data['itemListElement'][i]["image"]
            item_data = {
                "site" : site,
                "name" : name,
                "price": price,
                "bundle": bundle,
                "size": size,
                "image": image
            }

            cart.append(item_data)

        with open("cart.csv", "a", encoding='utf-8') as f:
            csv_dict_writer = csv.DictWriter(f, fieldnames=["site","name","price","bundle","size","image"])
            csv_dict_writer.writerows(cart)
    print("RedMart done")
    print("----------------------------------------")

#------------------------------------------------------------------
#  Giant Online
#------------------------------------------------------------------
    
def get_url2(keyword):
    print("Giant Online")
    driver = webdriver.Chrome()
    driver.get("https://giantonline.com.sg/")
    elem = driver.find_element_by_name("q")
    elem.clear()
    elem.send_keys(keyword)
    elem.send_keys(Keys.RETURN)

    keyword_to_url2 = driver.current_url
    driver.close()
    return keyword_to_url2

def collect_data2(keyword_to_url2):
    driver = webdriver.Chrome()    
    driver.get(keyword_to_url2)
    lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    match=False
    while(match==False):
            lastCount = lenOfPage
            time.sleep(3)
            lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount==lenOfPage:
                match=True

    soup = BeautifulSoup(driver.page_source, "html.parser")    

    cart = []
    
    boxes = soup.findAll("li", {"class":"col-xs-6 col-sm-4 col-md-3 col-lg-2 open-product-detail algolia-click"})
    total = len(boxes)
    print (f"Downloading {total} items")
    
    for box in boxes:
        site = "Giant"

        name = box.find("a", {"class":"product-link"}).text

        try:
            size = box.find("span", {"class":"size"}).text.replace("Size: ", "")
        except:
            size = 1
      
        try:
            price = box.find("div", {"class" : "price product-price"}).text.strip().replace("$","").split("/")[0]
        except:
            price = box.find("div", {"class" : "price product-price red"}).text.replace("$","").split("/")[0]

        try:
            bundle = box.find("span", {"class" : "product-discount-label mm-promo"}).text
        except:
            bundle = None

        #finds image of product
        image = box.find("img", {"class" : "img-responsive"})['src']

        item_data = {
            "site" : site,
            "name" : name,
            "price" : price,
            "bundle" : bundle,
            "size" : size,            
            "image" : image
        }

        cart.append(item_data)

    with open("cart.csv","a", encoding='utf-8') as f:
        csv_dict_writer = csv.DictWriter(f, fieldnames=["site","name","price","bundle","size","image"])
        csv_dict_writer.writerows(cart)
        
    driver.close()
    print("Giant Online done")
    print("----------------------------------------")

#------------------------------------------------------------------
#  Cold Storage
#------------------------------------------------------------------

def get_url3(keyword):
    print("Cold Storage")
    driver = webdriver.Chrome()
    driver.get("https://www.coldstorage.com.sg/")
    elem = driver.find_element_by_name("q")
    elem.clear()
    elem.send_keys(keyword)
    elem.send_keys(Keys.RETURN)

    keyword_to_url3 = driver.current_url
    driver.close()
    return keyword_to_url3
    
def collect_data3(keyword_to_url3):
    driver = webdriver.Chrome()    
    driver.get(keyword_to_url3)
    lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    match=False
    while(match==False):
            lastCount = lenOfPage
            time.sleep(3)
            lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount==lenOfPage:
                match=True

    soup = BeautifulSoup(driver.page_source, "html.parser")    

    cart = []
    
    boxes = soup.findAll("li", {"class":"col-xs-6 col-sm-4 col-md-3 col-lg-2 open-product-detail algolia-click"})
    total = len(boxes)
    print (f"Downloading {total} items")
    
    for box in boxes:
        site = "Cold Storage"

        name = box.find("a", {"class":"product-link"}).text


        try:
            size = box.find("span", {"class":"size"}).text.replace("Size: ", "")
        except:
            size = 1
       
        try:
            price = box.find("div", {"class" : "price product-price"}).text.strip().replace("$","").split("/")[0]
        except:
            price = box.find("div", {"class" : "price product-price red"}).text.replace("$","").split("/")[0]

        try:
            bundle = box.find("span", {"class" : "product-discount-label mm-promo"}).text
        except:
            bundle = None

        image = box.find("img", {"class" : "img-responsive"})['src']

        item_data = {
            "site" : site,
            "name" : name,
            "price" : price,
            "bundle" : bundle,
            "size" : size,            
            "image" : image
        }

        cart.append(item_data)

    with open("cart.csv","a", encoding='utf-8') as f:
        csv_dict_writer = csv.DictWriter(f, fieldnames=["site","name","price","bundle","size","image"])
        csv_dict_writer.writerows(cart)
        
    driver.close()
    print("Cold Storage done")
    print("----------------------------------------")

#------------------------------------------------------------------
#  Input search item
#------------------------------------------------------------------
    
keyword = input("Enter product to search: ")
startTime = datetime.now()
print("----------------------------------------")

keyword_to_url = get_url(keyword)
collect_data(keyword_to_url)

keyword_to_url2 = get_url2(keyword)
collect_data2(keyword_to_url2)

keyword_to_url3 = get_url3(keyword)
collect_data3(keyword_to_url3)

#------------------------------------------------------------------
#  Search end
#------------------------------------------------------------------
print("Scraping completed")
duration = datetime.now()-startTime 
print(f"Time taken: {duration}")
print("----------------------------------------")
# Out:
# Enter product to search: truffle oil
# ----------------------------------------
# RedMart
# Downloading 58 items
# RedMart done
# ----------------------------------------
# Giant Online
# Downloading 2 items
# Giant Online done
# ----------------------------------------
# Cold Storage
# Downloading 7 items
# Cold Storage done
# ----------------------------------------
# Scraping completed
# Time taken: 0:01:11.347245
# ----------------------------------------

# %% [markdown]
# ### Show all results

# %%
import pandas as pd
filename = r"C:\Users\Home\Desktop\PYDOT Proj\cart.csv"
df = pd.read_csv(filename, names = ['Site','Product','Price','Promo','Unit', 'Url'])
pd.set_option('display.max_rows', 5000) #display 5000 rows
df.style.background_gradient(cmap='summer', subset="Price")
# Out:
# <style  type="text/css" >
#     #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row1_col2 {
#             background-color:  #1c8e66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row2_col2 {
#             background-color:  #239166;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row3_col2 {
#             background-color:  #158a66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row4_col2 {
#             background-color:  #399c66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row5_col2 {
#             background-color:  #058266;
#             color:  #f1f1f1;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row6_col2 {
#             background-color:  #178b66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row7_col2 {
#             background-color:  #229066;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row8_col2 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row9_col2 {
#             background-color:  #329866;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row10_col2 {
#             background-color:  #2a9466;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row11_col2 {
#             background-color:  #1d8e66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row12_col2 {
#             background-color:  #4da666;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row13_col2 {
#             background-color:  #48a366;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row14_col2 {
#             background-color:  #259266;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row15_col2 {
#             background-color:  #7fbf66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row16_col2 {
#             background-color:  #48a366;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row17_col2 {
#             background-color:  #359a66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row18_col2 {
#             background-color:  #4da666;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row19_col2 {
#             background-color:  #4da666;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row20_col2 {
#             background-color:  #42a066;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row21_col2 {
#             background-color:  #47a366;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row22_col2 {
#             background-color:  #098466;
#             color:  #f1f1f1;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row23_col2 {
#             background-color:  #5eae66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row24_col2 {
#             background-color:  #379b66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row25_col2 {
#             background-color:  #9ece66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row26_col2 {
#             background-color:  #379b66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row27_col2 {
#             background-color:  #1d8e66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row28_col2 {
#             background-color:  #4ba566;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row29_col2 {
#             background-color:  #64b266;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row30_col2 {
#             background-color:  #79bc66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row31_col2 {
#             background-color:  #379b66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row32_col2 {
#             background-color:  #54aa66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row33_col2 {
#             background-color:  #3c9e66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row34_col2 {
#             background-color:  #76bb66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row35_col2 {
#             background-color:  #5aac66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row36_col2 {
#             background-color:  #42a066;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row37_col2 {
#             background-color:  #51a866;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row38_col2 {
#             background-color:  #b3d966;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row39_col2 {
#             background-color:  #67b366;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row40_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row41_col2 {
#             background-color:  #57ab66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row42_col2 {
#             background-color:  #399c66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row43_col2 {
#             background-color:  #47a366;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row44_col2 {
#             background-color:  #67b366;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row45_col2 {
#             background-color:  #5bad66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row46_col2 {
#             background-color:  #65b266;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row47_col2 {
#             background-color:  #65b266;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row48_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row49_col2 {
#             background-color:  #058266;
#             color:  #f1f1f1;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row50_col2 {
#             background-color:  #a4d266;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row51_col2 {
#             background-color:  #9ece66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row52_col2 {
#             background-color:  #3f9f66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row53_col2 {
#             background-color:  #158a66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row54_col2 {
#             background-color:  #79bc66;
#             color:  #000000;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row55_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9row56_col2 {
#             background-color:  #058266;
#             color:  #f1f1f1;
#         }</style><table id="T_2e1eaff0_8372_11e9_8741_3497f6cbfdb9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Site</th>        <th class="col_heading level0 col1" >Product</th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Promo</th>        <th

# %% [markdown]
# ### Get Items on Promo (if any)

# %%
df[["Site","Product","Price","Promo","Unit"]].dropna()
# Out:
# Empty DataFrame
# Columns: [Site, Product, Price, Promo, Unit]
# Index: []

# %% [markdown]
# ### Shows X lowest price products

# %%
num = 10
print(f"Top {num} lowest price products")
df[["Site","Product","Price","Unit"]].nsmallest(num, 'Price').style.background_gradient(cmap='summer', subset="Price")
# Out:
# Top 10 lowest price products
# <style  type="text/css" >
#     #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row1_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row3_col2 {
#             background-color:  #3b9d66;
#             color:  #000000;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row4_col2 {
#             background-color:  #3b9d66;
#             color:  #000000;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row5_col2 {
#             background-color:  #3b9d66;
#             color:  #000000;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row6_col2 {
#             background-color:  #6cb666;
#             color:  #000000;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row7_col2 {
#             background-color:  #eff766;
#             color:  #000000;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row8_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row9_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Site</th>        <th class="col_heading level0 col1" >Product</th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Unit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row0_col0" class="data row0 col0" >RedMart</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row0_col1" class="data row0 col1" >Naturel Extra Virgin Olive Spray - White Truffle Flavoured</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row0_col2" class="data row0 col2" >6.25</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row0_col3" class="data row0 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row1" class="row_heading level0 row1" >48</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row1_col0" class="data row1 col0" >Giant</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row1_col1" class="data row1 col1" >Extra Virgin Olive Spray Oil With White Truffle 200ml</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row1_col2" class="data row1 col2" >6.25</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row1_col3" class="data row1 col3" >200ML</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row2" class="row_heading level0 row2" >55</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row2_col0" class="data row2 col0" >Cold Storage</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row2_col1" class="data row2 col1" >Extra Virgin Olive Spray Oil With White Truffle 200ml</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row2_col2" class="data row2 col2" >6.25</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row2_col3" class="data row2 col3" >200ML</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row3_col0" class="data row3 col0" >RedMart</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row3_col1" class="data row3 col1" >Naturel Extra Virgin Olive Oil - White Truffle Flavoured</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row3_col2" class="data row3 col2" >7.9</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row3_col3" class="data row3 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row4" class="row_heading level0 row4" >49</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row4_col0" class="data row4 col0" >Giant</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row4_col1" class="data row4 col1" >Extra Virgin Olive With Truffle 250ml</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row4_col2" class="data row4 col2" >7.9</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row4_col3" class="data row4 col3" >250ML</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row5" class="row_heading level0 row5" >56</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row5_col0" class="data row5 col0" >Cold Storage</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row5_col1" class="data row5 col1" >Extra Virgin Olive With Truffle 250ml</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row5_col2" class="data row5 col2" >7.9</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row5_col3" class="data row5 col3" >250ML</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row6" class="row_heading level0 row6" >22</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row6_col0" class="data row6 col0" >RedMart</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row6_col1" class="data row6 col1" >Iliada Sliver Line Extra Virgin Olive Oil With Truffle Flavour</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row6_col2" class="data row6 col2" >9.26</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row6_col3" class="data row6 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row7_col0" class="data row7 col0" >RedMart</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row7_col1" class="data row7 col1" >Longhi White Truffle Oil with white truffle leaf</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row7_col2" class="data row7 col2" >12.9</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row7_col3" class="data row7 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row8" class="row_heading level0 row8" >3</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row8_col0" class="data row8 col0" >RedMart</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row8_col1" class="data row8 col1" >Mantova Spray (Italian) Truffle Infused Extra Virgin Olive Oil</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row8_col2" class="data row8 col2" >13.35</td>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row8_col3" class="data row8 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9level0_row9" class="row_heading level0 row9" >53</th>
#                         <td id="T_3f03ac54_8372_11e9_8bb3_3497f6cbfdb9row9_col0" class="data row9 col0" >Cold Storage</td>

# %%
#Try searching
#Truffle oil
#Hokkaido scallop
#Magnolia omega plus 1l
